# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from torchsummary import summary
import matplotlib.pyplot as plt

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Load dữ liệu từ bộ dữ liệu MNIST
train_dataset = MNIST(root='./data', train=True, transform=ToTensor(), download=True)
test_dataset = MNIST(root='./data', train=False, transform=ToTensor())

# %%
# Tạo DataLoader tải dữ liệu dạng batch
train_loader = DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=64, shuffle=False)

# %%
# Mô hình ANN
class ANN(nn.Module):
    def __init__(self):
        super(ANN, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(28*28, 128)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 10)
        self.softmax = nn.Softmax(dim=1)
        
    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.softmax(x)
        return x

# %%
model = ANN().to(device)

# %%
# Hàm loss và optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
train_loss_history = []
train_acc_history = []
# Huấn luyện mô hình
num_epochs = 10
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{total_step}], Loss: {loss.item():.4f}')
    # Đánh giá trên tập huấn luyện và tính accuracy
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_accuracy = correct / total
        train_loss_history.append(loss.item())
        train_acc_history.append(train_accuracy)
        print(f'Train Accuracy: {100*train_accuracy:.2f}%')
    #Tính accuracy trên tập kiểm tra
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        test_accuracy = correct / total
        print(f'Test Accuracy: {100*test_accuracy:.2f}%')
# Out:
# Epoch [1/10], Step [100/938], Loss: 1.7720
# Epoch [1/10], Step [200/938], Loss: 1.6141
# Epoch [1/10], Step [300/938], Loss: 1.6007
# Epoch [1/10], Step [400/938], Loss: 1.5685
# Epoch [1/10], Step [500/938], Loss: 1.5589
# Epoch [1/10], Step [600/938], Loss: 1.5705
# Epoch [1/10], Step [700/938], Loss: 1.5519
# Epoch [1/10], Step [800/938], Loss: 1.5102
# Epoch [1/10], Step [900/938], Loss: 1.5036
# Train Accuracy: 93.31%
# Test Accuracy: 93.16%
# Epoch [2/10], Step [100/938], Loss: 1.5182
# Epoch [2/10], Step [200/938], Loss: 1.5128
# Epoch [2/10], Step [300/938], Loss: 1.5147
# Epoch [2/10], Step [400/938], Loss: 1.5398
# Epoch [2/10], Step [500/938], Loss: 1.5684
# Epoch [2/10], Step [600/938], Loss: 1.5376
# Epoch [2/10], Step [700/938], Loss: 1.5417
# Epoch [2/10], Step [800/938], Loss: 1.4932
# Epoch [2/10], Step [900/938], Loss: 1.4814
# Train Accuracy: 94.85%
# Test Accuracy: 94.35%
# Epoch [3/10], Step [100/938], Loss: 1.5357
# Epoch [3/10], Step [200/938], Loss: 1.5000
# Epoch [3/10], Step [300/938], Loss: 1.5230
# Epoch [3/10], Step [400/938], Loss: 1.5541
# Epoch [3/10], Step [500/938], Loss: 1.5214
# Epoch [3/10], Step [600/938], Loss: 1.5215
# Epoch [3/10], Step [700/938], Loss: 1.5290
# Epoch [3/10], Step [800/938], Loss: 1.5879
# Epoch [3/10], Step [900/938], Loss: 1.5034
# Train Accuracy: 95.95%
# Test Accuracy: 95.50%
# Epoch [4/10], Step [100/938], Loss: 1.4839
# Epoch [4/10], Step [200/938], Loss: 1.5147
# Epoch [4/10], Step [300/938], Loss: 1.5131
# Epoch [4/10], Step [400/938], Loss: 1.5310
# Epoch [4/10], Step [500/938], Loss: 1.5128
# Epoch [4/10], Step [600/938], Loss: 1.4715
# Epoch [4/10], Step [700/938], Loss: 1.5122
# Epoch [4/10], Step [800/938], Loss: 1.5142
# Epoch [4/10], Step [900/938], Loss: 1.5443
# Train Accuracy: 96.56%
# Test Accuracy: 95.86%
# Epoch [5/10], Step [100/938], Loss: 1.4902
# Epoch [5/10], Step [200/938], Loss: 1.4784
# Epoch [5/10], Step [300/938], Loss: 1.5119
# Epoch [5/10], Step [400/938], Loss: 1.4805
# Epoch [5/10], Step [500/938], Loss: 1.4698
# Epoch [5/10], Step [600/938], Loss: 1.4782
# Epoch [5/10], Step [700/938], Loss: 1.5433
# Epoch [5/10], Step [800/938], Loss: 1.5065
# Epoch [5/10], Step [900/938], Loss: 1.5120
# Train Accuracy: 97.25%
# Test Accuracy: 96.37%
# Epoch [6/10], Step [100/938], Loss: 1.4649
# Epoch [6/10], Step [200/938], Loss: 1.5488
# Epoch [6/10], Step [300/938], Loss: 1.4821
# Epoch [6/10], Step [400/938], Loss: 1.4887
# Epoch [6/10], Step [500/938], Loss: 1.5036
# Epoch [6/10], Step [600/938], Loss: 1.4780
# Epoch [6/10], Step [700/938], Loss: 1.5103
# Epoch [6/10], Step [800/938], Loss: 1.5287
# Epoch [6/10], Step [900/938], Loss: 1.4961
# Train Accuracy: 97.52%
# Test Accuracy: 96.54%
# Epoch [7/10], Step [100/938], Loss: 1.5246
# Epoch [7/10], Step [200/938], Loss: 1.5049
# Epoch [7/10], Step [300/938], Loss: 1.4755
# Epoch [7/10], Step [400/938], Loss: 1.4789
# Epoch [7/10], Step [500/938], Loss: 1.4884
# Epoch [7/10], Step [600/938], Loss: 1.4931
# Epoch [7/10], Step [700/938], Loss: 1.4628
# Epoch [7/10], Step [800/938], Loss: 1.4759
# Epoch [7/10], Step [900/938], Loss: 1.5028
# Train Accuracy: 97.71%
# Test Accuracy: 96.80%
# Epoch [8/10], Step [100/938], Loss: 1.4652
# Epoch [8/10], Step [200/938], Loss: 1.4951
# Epoch [8/10], Step [300/938], Loss: 1.4685
# Epoch [8/10], Step [400/938], Loss: 1.5247
# Epoch [8/10], Step [500/938], Loss: 1.4915
# Epoch [8/10], Step [600/938], Loss: 1.5053
# Epoch [8/10], Step [700/938], Loss: 1.4914
# Epoch [8/10], Step [800/938], Loss: 1.5007
# Epoch [8/10], Step [900/938], Loss: 1.4639
# Train Accuracy: 98.11%
# Test Accuracy: 97.16%
# Epoch [9/10], Step [100/938], Loss: 1.5236
# Epoch [9/10], Step [200/938], Loss: 1.4908
# Epoch [9/10], Step [300/938], Loss: 1.4648
# Epoch [9/10], Step [400/938], Loss: 1.4671
# Epoch [9/10], Step [500/938], Loss: 1.4803
# Epoch [9/10], Step [600/938], Loss: 1.4936
# Epoch [9/10], Step [700/938], Loss: 1.5104
# Epoch [9/10], Step [800/938], Loss: 1.4848
# Epoch [9/10], Step [900/938], Loss: 1.5013
# Train Accuracy: 97.82%
# Test Accuracy: 96.61%
# Epoch [10/10], Step [100/938], Loss: 1.4900
# Epoch [10/10], Step [200/938], Loss: 1.4778
# Epoch [10/10], Step [300/938], Loss: 1.5123
# Epoch [10/10], Step [400/938], Loss: 1.4990
# Epoch [10/10], Step [500/938], Loss: 1.4707
# Epoch [10/10], Step [600/938], Loss: 1.4703
# Epoch [10/10], Step [700/938], Loss: 1.4853
# Epoch [10/10], Step [800/938], Loss: 1.4967
# Epoch [10/10], Step [900/938], Loss: 1.4773
# Train Accuracy: 98.40%
# Test Accuracy: 97.38%

# %%
# Đồ thị loss và accuracy
epochs = range(1, num_epochs+1)
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss_history, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc_history, label='Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy')
plt.legend()
plt.tight_layout()
plt.show()
